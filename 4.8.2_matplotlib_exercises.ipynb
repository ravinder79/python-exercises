# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Use matplotlib to plot the following equation:
#
# y=x2−x+2
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
x = range(-100,100)


y = [(x**2 - x + 2) for x in x ]

plt.plot(x,y)
plt.title('$y = x2 -x + 2$')
plt.annotate('Origin', xy=(0, 0), xytext=(0, 2500),
             arrowprops={'facecolor': 'blue'})
plt.xlabel("x")
plt.ylabel("y", rotation = 0)
plt.show()

# %% [markdown]
# import math
# x = range(0,20)
# y1 = [math.sqrt(x) for x in x]
# plt.plot(x,y1)

# %%
import math
x = range(0,100)
y1 = [math.sqrt(x) for x in x]
plt.title('$y = \sqrt{x}$')
plt.xlabel("x")
plt.ylabel("$sqrt(x)$", rotation = 0)
plt.plot(x,y1)

# %%
x = range(0,100)
y2 = [x**3 for x in x]
plt.title('$y = x^3$')
plt.xlabel("x")
plt.ylabel("y", rotation = 0)
plt.plot(x,y2)

# %%
import numpy as np
x = np.linspace(-2 * math.pi, 2 * math.pi, 1000)
#x = [i* math.pi/32 for i in range (-120,120) ]
y = np.tan(x)
#y3 = [math.tan(x1) for x1 in x1]
y[:-1][np.diff(y)<0] = np.nan
plt.xlabel("x")
plt.grid()
plt.ylabel("$tan(x)$", rotation = 0)
plt.title('$y = tan(x)$')
radian_multiples = [-2, -3/2, -1, -1/2, 0, 1/2, 1, 3/2, 2]
radians = [n * math.pi for n in radian_multiples]
radian_labels = ['$-2\pi$', '$-3\pi/2$', '$\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
plt.xticks(radians, radian_labels)
plt.plot(x,y)
plt.ylim(-7, 7)
plt.xlim(-2*math.pi, 2*math.pi)
# Out:
# (-6.283185307179586, 6.283185307179586)

# %%
x = range(0,15)
y4 = [2**x for x in x]
plt.xlabel("x")
plt.ylabel("$2^x$", rotation = 0)
plt.title('$y = 2^x$')
#plt.yscale('log')
plt.yscale('linear')
plt.plot(x,y4)

# %%
import math

plt.figure(figsize=(16, 9))
plt.subplot(2,2,1)
x = range(0,20)
y1 = [math.sqrt(x) for x in x]
plt.title("$y=\sqrt{x}$")
plt.xlabel("x")
plt.grid()
plt.plot(x,y1)



plt.subplot(2,2,2)
x = range(0,20)
y2 = [x**3 for x in x]
plt.title("x^3")
plt.xlabel("x")
plt.grid()
plt.plot(x,y2)


plt.subplot(2,2,3)
import numpy as np
x = np.linspace(-2 * math.pi, 2 * math.pi, 1000)
#x = [i* math.pi/32 for i in range (-120,120) ]
y = np.tan(x)
#y3 = [math.tan(x1) for x1 in x1]
y[:-1][np.diff(y)<0] = np.nan
plt.xlabel("x")
plt.grid()
plt.ylabel("$tan(x)$", rotation = 0)
plt.title('$y = tan(x)$')
radian_multiples = [-2, -3/2, -1, -1/2, 0, 1/2, 1, 3/2, 2]
radians = [n * math.pi for n in radian_multiples]
radian_labels = ['$-2\pi$', '$-3\pi/2$', '$\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$', '$3\pi/2$', '$2\pi$']
plt.xticks(radians, radian_labels)
plt.plot(x,y)
plt.ylim(-7, 7)
plt.xlim(-2*math.pi, 2*math.pi)


plt.subplot(2,2,4)
x = range(0,20)
plt.xlabel("x")
y4 = [2**x for x in x]
plt.title("$y=2^x$")
plt.grid()
plt.plot(x,y4)

# %%
import math
#x1 = range(0,10)
x1 = [i* math.pi/32 for i in range (0,100)]
x = [i*1 for i in range(0,10)]
y1 = [math.sqrt(x) for x in x]
y2 = [x**3 for x in x1]
y3 = [math.tan(x) for x in x1]
y4 = [2**x for x in x1]
plt.figure(figsize=(16, 9))

plt.plot(x,y1, label = '$sqrt(x)$')
plt.plot(x1,y2, label = '$x^3$')
plt.plot(x1,y3, label = '$tan(x)$')
plt.plot(x1,y4, label = '$2^x$')
plt.legend(loc='best')
plt.ylim(-10,10)
plt.xlim(0,10)
# Out:
# (0, 10)

# %% [markdown]
#     Write the code necessary to write your name on a chart. Use box letters. Bonus: use curves for letters in your name that have curves in them. RAVINDER

# %%
plt.vlines(x = 1, ymin = 1.0, ymax = 3.0)
plt.xlim(0,10)
plt.ylim(0,5)
xmax =10

x1 = [i* 0.25 for i in range (4,7)]
y1 = [(-2*x+4) for x in x1] 
plt.plot(x1,y1)

x2 = [i*0.1 for i in range (10, 15)]
y2= [math.sqrt(0.25-((x-1)**2))+3 for x in x2]
